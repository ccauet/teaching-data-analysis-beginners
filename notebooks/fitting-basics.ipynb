# %%
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

import scipy.optimize as opt

# %matplotlib inline

plt.rcParams['figure.figsize'] = (16.0, 8.0)
plt.style.use('ggplot')

# %%
n_sample = 20
x = np.linspace(-2, 2, n_sample)
y = 1 * np.random.normal(0, 1, size=n_sample) + 3 * x**2

# %%
plt.plot(x, y, '+', color='dodgerblue')

# %%
def linear(x, intercept, slope):
    return intercept + slope * x

# %%
def quadratic(x, a, b):
    return a + b * x**2

# %%
params, cov = opt.curve_fit(quadratic, x, y)

# %%
params
# Out:
# array([-0.11813549,  2.93998311])

# %%
plt.plot(x, y, marker='+', linewidth=0, color='dodgerblue', label='Data points');
plt.plot(x, quadratic(x, 0, 3), label='Truth w/o random pertubation', color='gray', alpha=0.5)
plt.plot(x, quadratic(x, *params), label='Linear fit')
plt.legend();

# %%
cov
# Out:
# array([[ 2.05425720e-01, -6.10102330e-11],
#        [-6.10102330e-11,  1.26056692e-01]])
